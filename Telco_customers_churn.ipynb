# %% [markdown]
# **📌 1. Data Loading & Initial Inspection**
#
#    * Import all the Required Libaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loaded the Telco Customer Churn dataset**

# %%
data =pd.read_csv("E:/Projects/Teleco project/Telco_Customer_Churn.csv")
print(data)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# **Checking the data from Starting**

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **Checking the data from Bottom**

# %%
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# **Checking the Shape of data // How much Columns & Rows**

# %%
data.shape
# Out:
# (7043, 21)

# %% [markdown]
# **Checking the Columns names present in the data**

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **Checking the DataTypes of the Columns**

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# **Checking the a Brief Information about the data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# **Checking the Small describition about the data**

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **Converting the SeniorCitizen values from 0/1 to Yes/No**

# %%
data['SeniorCitizen'] = data['SeniorCitizen'].replace({1:'Yes',0:'No'})

# %% [markdown]
# **Checking the columns Senior Citizen**

# %%
data['SeniorCitizen']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: SeniorCitizen, Length: 7043, dtype: object

# %%
data.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.describe()
# Out:
#             tenure  MonthlyCharges
# count  7043.000000     7043.000000
# mean     32.371149       64.761692
# std      24.559481       30.090047
# min       0.000000       18.250000
# 25%       9.000000       35.500000
# 50%      29.000000       70.350000
# 75%      55.000000       89.850000
# max      72.000000      118.750000

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **Changing the datatype of columns(Total Charges) from object to float or numeric**

# %%
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors = 'coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **Checking the Count value of Churn column**

# %%
data['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# **Checking the Count value of Churn column in percentage**

# %%
data['Churn'].value_counts()/len(data)*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: count, dtype: float64

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **📌  Target Variable (Churn) Encoding**
#
#     * Verified class distribution using value_counts()
#
# **Insight**
#
# **The target variable was transformed into a binary format to enable churn-based analysis
# and future modeling while ensuring both churned and non-churned customers were retained.**

# %%
data['Churn'].value_counts().plot( kind = 'bar', color = 'red',figsize = (6,4) )
plt.xlabel("Target Varible")
plt.ylabel("Counts")
plt.title("Counts of Targets Varibles")
# Out:
# Text(0.5, 1.0, 'Counts of Targets Varibles')

# %% [markdown]
# **Checking is there is Missing/Null value present or not**

# %%
data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# **We found some missing value  on column (Total charges) and now we fixing it**

# %%
data.dropna(how = 'any' , inplace = True)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# **Checing the Maximum number from column (Tenure)**

# %%
print(data['tenure'].max())
# Out:
# 72

# %% [markdown]
# **Converting the Tenure column into groups (1-12 , 13-24, 25-36)**

# %%
labels= ["{0} - {1}".format(i, i + 11)for i in range (1,72,12)]
print(labels)
# Out:
# ['1 - 12', '13 - 24', '25 - 36', '37 - 48', '49 - 60', '61 - 72']

# %%
data["tenure_group"] = pd.cut(data.tenure , range(1,80,12), right = False, labels = labels)

# %% [markdown]
# **Checking the value Count of Each group we made for Tenure**

# %%
data["tenure_group"].value_counts()
# Out:
# tenure_group
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'tenure_group'],
#       dtype='object')

# %%
data['tenure_group'].value_counts().plot (kind = 'bar', figsize =(6,4),color = 'green')
plt.xlabel("Tenure Categories")
plt.ylabel("Counts")
plt.title("Counts of Total Tenures ")
# Out:
# Text(0.5, 1.0, 'Counts of Total Tenures ')

# %%
data.head(3)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges TotalCharges  Churn  tenure_group
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'tenure_group'],
#       dtype='object')

# %%
data.drop(columns = ['customerID','tenure'],axis = 1, inplace = True)

# %%
data.head(3)
# Out:
#    gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female            No     Yes         No           No  No phone service
# 1    Male            No      No         No          Yes                No
# 2    Male            No      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges Churn tenure_group
# ...

# %%
data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn', 'tenure_group'],
#       dtype='object')

# %%
for i , predictor in enumerate(data.drop(columns=['MonthlyCharges','TotalCharges','Churn'],)):
    plt.figure(i)
    sns.countplot(data,x =predictor ,hue='Churn' , )

# %%
data.head(3)
# Out:
#    gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female            No     Yes         No           No  No phone service
# 1    Male            No      No         No          Yes                No
# 2    Male            No      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges Churn tenure_group
# ...

# %%
data_target0 = data[data['Churn']=='No']
data_target1 = data[data['Churn']=='Yes']

# %%
data_target1.gender.value_counts()
# Out:
# gender
# Female    939
# Male      930
# Name: count, dtype: int64

# %%
data_target0.gender.value_counts()
# Out:
# gender
# Male      2619
# Female    2544
# Name: count, dtype: int64

# %%
data.gender.value_counts()
# Out:
# gender
# Male      3549
# Female    3483
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn', 'tenure_group'],
#       dtype='object')

# %%
pd.crosstab(data.PaymentMethod,data.Churn)
# Out:
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1284   258
# Credit card (automatic)    1289   232
# Electronic check           1294  1071
# Mailed check               1296   308

# %%
data['Churn'].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female            No     Yes         No           No  No phone service
# 1    Male            No      No         No          Yes                No
# 2    Male            No      No         No          Yes                No
# 3    Male            No      No         No           No  No phone service
# 4  Female            No      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
data['Churn'] = data['Churn'].str.strip().str.capitalize()
data['Churn'] = data['Churn'].map({'No': 0, 'Yes': 1})

# %%
data.head()
# Out:
#    gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female            No     Yes         No           No  No phone service
# 1    Male            No      No         No          Yes                No
# 2    Male            No      No         No          Yes                No
# 3    Male            No      No         No           No  No phone service
# 4  Female            No      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
data_dummies = pd.get_dummies(data).astype(int)
data_dummies.head()
# Out:
#    MonthlyCharges  TotalCharges  Churn  gender_Female  gender_Male  \
# 0              29            29      0              1            0
# 1              56          1889      0              0            1
# 2              53           108      1              0            1
# 3              42          1840      0              0            1
# 4              70           151      1              1            0
#
#    SeniorCitizen_No  SeniorCitizen_Yes  Partner_No  Partner_Yes  \
# 0                 1                  0           0            1
# 1                 1                  0           1            0
# 2                 1                  0           1            0
# 3                 1                  0           1            0
# 4                 1                  0           1            0
#
#    Dependents_No  ...  PaymentMethod_Bank transfer (automatic)  \
# 0              1  ...                                        0
# ...

# %%
data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn', 'tenure_group'],
#       dtype='object')

# %%
data_dummies['MonthlyCharges'].corr(data_dummies['TotalCharges'])
# Out:
# np.float64(0.6511252380434775)

# %%
# Relationship betweem Monthycharges and Totalcharges
sns.lmplot(data=data_dummies , x = 'MonthlyCharges' , y = 'TotalCharges' )

# %%
# Building the corelation of all predication wiht churn

# %%
plt.figure(figsize = (20,8))
data_dummies.corr()['Churn'].sort_values(ascending  = False).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
data_dummies.corr()['Churn']
# Out:
# MonthlyCharges                             0.192922
# TotalCharges                              -0.199485
# Churn                                      1.000000
# gender_Female                              0.008545
# gender_Male                               -0.008545
# SeniorCitizen_No                          -0.150541
# SeniorCitizen_Yes                          0.150541
# Partner_No                                 0.149982
# Partner_Yes                               -0.149982
# Dependents_No                              0.163128
# Dependents_Yes                            -0.163128
# PhoneService_No                           -0.011691
# PhoneService_Yes                           0.011691
# MultipleLines_No                          -0.032654
# MultipleLines_No phone service            -0.011691
# MultipleLines_Yes                          0.040033
# InternetService_DSL                       -0.124141
# InternetService_Fiber optic                0.307463
# ...

# %%
dt = sns.kdeplot(data_dummies.MonthlyCharges[(data_dummies["Churn"]==0)],color = 'blue',fill = True)
dt = sns.kdeplot(data_dummies.MonthlyCharges[(data_dummies["Churn"]==1)],ax = dt,color = 'red', fill = True)

dt.legend(["No Churn","Churn"] , loc = 'upper right')
dt.set_ylabel('Density')
dt.set_xlabel('Monthly charges')
dt.set_title('Monthly chagres by chrun')
# Out:
# Text(0.5, 1.0, 'Monthly chagres by chrun')

# %%
data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn', 'tenure_group'],
#       dtype='object')

# %%
plt.figure(figsize=(6,4))
sns.countplot(
    data=data,
    x='MultipleLines',
    hue='gender'
)
plt.title('Contract vs Gender')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(
    data=data,
    x='InternetService',
    hue='gender'
)
plt.title('Contract vs Gender')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(
    data=data,
    x='Contract',
    hue='gender'
)
plt.title('Contract vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='PaymentMethod',
    hue='gender'
)
plt.title('Contract vs Gender')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(
    data=data,
    x='Churn',
    hue='gender'
)
plt.title('Contract vs Gender')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(
    data=data,
    x='tenure_group',
    hue='gender'
)
plt.title('Contract vs Gender')
plt.show()
